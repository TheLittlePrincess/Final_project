# %% [markdown]
# <a href="https://colab.research.google.com/github/TheLittlePrincess/Final_project/blob/Ana_W2/routes_with_zips_S3_and_github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# replacing files on the drive for those on the S3
# S3 link to be used:      s3://finalprojectaustintrash
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !sudo pip install geopandas
# !sudo pip install pygeos
# !pip install rtree
# !sudo apt-get install -y libspatialindex-dev
# !sudo apt-get install -y python-rtree
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.7/dist-packages (0.9.0)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.20)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (3.1.0)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.1.5)
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2020.12.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (56.1.0)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (21.2.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: munch in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->geopandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->geopandas) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->geopandas) (1.19.5)
# Requirement already satisfied: pygeos in /usr/local/lib/python3.7/dist-packages (0.10)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.7/dist-packages (from pygeos) (1.19.5)
# Requirement already satisfied: rtree in /usr/local/lib/python3.7/dist-packages (0.9.7)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libspatialindex-dev is already the newest version (1.8.5-5).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-rtree is already the newest version (0.8.3+ds-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.

# %%
#new to S3 use
# !pip install fsspec
# Out:
# Requirement already satisfied: fsspec in /usr/local/lib/python3.7/dist-packages (2021.5.0)

# %%
#new for S3 use
# !pip install s3fs
# Out:
# Requirement already satisfied: s3fs in /usr/local/lib/python3.7/dist-packages (2021.5.0)
# Requirement already satisfied: fsspec==2021.05.0 in /usr/local/lib/python3.7/dist-packages (from s3fs) (2021.5.0)
# Requirement already satisfied: aiobotocore>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from s3fs) (1.3.0)
# Requirement already satisfied: aioitertools>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from aiobotocore>=1.0.1->s3fs) (0.7.1)
# Requirement already satisfied: wrapt>=1.10.10 in /usr/local/lib/python3.7/dist-packages (from aiobotocore>=1.0.1->s3fs) (1.12.1)
# Requirement already satisfied: botocore<1.20.50,>=1.20.49 in /usr/local/lib/python3.7/dist-packages (from aiobotocore>=1.0.1->s3fs) (1.20.49)
# Requirement already satisfied: aiohttp>=3.3.1 in /usr/local/lib/python3.7/dist-packages (from aiobotocore>=1.0.1->s3fs) (3.7.4.post0)
# Requirement already satisfied: typing_extensions>=3.7 in /usr/local/lib/python3.7/dist-packages (from aioitertools>=0.5.1->aiobotocore>=1.0.1->s3fs) (3.7.4.3)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.7/dist-packages (from botocore<1.20.50,>=1.20.49->aiobotocore>=1.0.1->s3fs) (1.26.5)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.20.50,>=1.20.49->aiobotocore>=1.0.1->s3fs) (2.8.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.20.50,>=1.20.49->aiobotocore>=1.0.1->s3fs) (0.10.0)
# Requirement already satisfied: chardet<5.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp>=3.3.1->aiobotocore>=1.0.1->s3fs) (3.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp>=3.3.1->aiobotocore>=1.0.1->s3fs) (5.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp>=3.3.1->aiobotocore>=1.0.1->s3fs) (21.2.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp>=3.3.1->aiobotocore>=1.0.1->s3fs) (3.0.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp>=3.3.1->aiobotocore>=1.0.1->s3fs) (1.6.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.20.50,>=1.20.49->aiobotocore>=1.0.1->s3fs) (1.15.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp>=3.3.1->aiobotocore>=1.0.1->s3fs) (2.10)

# %%
import pandas as pd
import numpy as np
import csv
import geopandas as gpd
from shapely.geometry import Polygon, mapping, Point
from rtree import Rtree
import pygeos

# %%
#read the routes file that contains one point per route
routes = pd.read_csv("s3://finalprojectaustintrash/Routes_Tableau.csv")

# %%
routes.head()
# Out:
#   Garb Rt  ... Longitude (generated)
# 0    PW41  ...            -97.669893
# 1    PW40  ...            -97.674997
# 2    PW32  ...            -97.641614
# 3    PW31  ...            -97.683817
# 4    PW30  ...            -97.662850
#
# [5 rows x 4 columns]

# %%
#routes to dataframe
#routes_df = gpd.GeoDataFrame(routes, geometry=gpd.points_from_xy(routes["Longitude (generated)"], routes["Latitude (generated)"]))

# %%
#trouble shooting for reading
#zips_forread= pd.read_csv("s3://finalprojectaustintrash/austin_area_zip_codes.csv")

# %%
zips_forread.head()
# Out:
#                                             the_geom  ...                     updated_at
# 0  0106000020E61000000100000001030000000100000077...  ...  2015-06-07 00:48:14.456593+00
# 1  0106000020E61000000100000001030000000100000023...  ...  2015-06-07 00:48:14.456593+00
# 2  0106000020E6100000010000000103000000010000004E...  ...  2015-06-07 00:48:14.456593+00
# 3  0106000020E610000001000000010300000001000000FA...  ...  2015-06-07 00:48:14.456593+00
# 4  0106000020E61000000100000001030000000100000048...  ...  2015-06-07 00:48:14.456593+00
#
# [5 rows x 15 columns]

# %%
#zips = gpd.read_file("s3://finalprojectaustintrash/austin_area_zip_codes.csv",GEOM_POSSIBLE_NAMES="the_geom", KEEP_GEOM_COLUMNS="NO")

# %%
# download csv file from GitHub public repo using wget
# !wget "https://raw.githubusercontent.com/TheLittlePrincess/Final_project/main/austin_area_zip_codes.csv"
# Out:
# --2021-06-01 18:52:16--  https://raw.githubusercontent.com/TheLittlePrincess/Final_project/main/austin_area_zip_codes.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1231882 (1.2M) [text/plain]
# Saving to: ‘austin_area_zip_codes.csv’
#
# austin_area_zip_cod 100%[===================>]   1.17M  --.-KB/s    in 0.1s
#
# 2021-06-01 18:52:16 (9.93 MB/s) - ‘austin_area_zip_codes.csv’ saved [1231882/1231882]

# %%
# confirm the file was downloaded
# !ls

# %%
# check file location and create base directory variable
# base_dir will be a list with a single list item, but we need it to be a string
# so we'll just grab the first index
base_dir = !pwd
# !pwd
type(base_dir[0])
# Out:
# /content
# str

# %%
# use base directory and filename to create the geopandas dataframe
zips = gpd.read_file(f"{base_dir[0]}/austin_area_zip_codes.csv",GEOM_POSSIBLE_NAMES="the_geom", KEEP_GEOM_COLUMNS="NO")
zips.head()
# Out:
#   geodb_oid  ...                                           geometry
# 0         3  ...  MULTIPOLYGON (((-97.89002 30.20941, -97.88929 ...
# 1         4  ...  MULTIPOLYGON (((-97.91075 30.50110, -97.91053 ...
# 2        16  ...  MULTIPOLYGON (((-97.27371 30.29662, -97.27323 ...
# 3        17  ...  MULTIPOLYGON (((-97.73690 29.78761, -97.73582 ...
# 4        18  ...  MULTIPOLYGON (((-97.51624 30.21906, -97.51600 ...
#
# [5 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (20, 20)

# %%
fig, ax = plt.subplots()

zips.geometry.plot(color=None, edgecolor='k',linewidth = 2,ax=ax)
routes_df.geometry.plot(color='Orange', edgecolor='k',linewidth = 2,ax=ax)

# %%
zip_coords = zips[['zipcode','geometry']]

route_coords = routes_df[['Garb Rt','geometry']]

# %%
zip_coords
# Out:
#    zipcode                                           geometry
# 0    78739  MULTIPOLYGON (((-97.89002 30.20941, -97.88929 ...
# 1    78645  MULTIPOLYGON (((-97.91075 30.50110, -97.91053 ...
# 2    78602  MULTIPOLYGON (((-97.27371 30.29662, -97.27323 ...
# 3    78655  MULTIPOLYGON (((-97.73690 29.78761, -97.73582 ...
# 4    78617  MULTIPOLYGON (((-97.51624 30.21906, -97.51600 ...
# ..     ...                                                ...
# 75   78660  MULTIPOLYGON (((-97.57653 30.50086, -97.57450 ...
# 76   78662  MULTIPOLYGON (((-97.45105 30.01521, -97.44517 ...
# 77   78705  MULTIPOLYGON (((-97.72978 30.29871, -97.72893 ...
# 78   78701  MULTIPOLYGON (((-97.73599 30.25101, -97.73589 ...
# 79   78759  MULTIPOLYGON (((-97.74744 30.42162, -97.74721 ...
#
# [80 rows x 2 columns]

# %%
route_coords
# Out:
#     Garb Rt                    geometry
# 0      PW41  POINT (-97.66989 30.35876)
# 1      PW40  POINT (-97.67500 30.36326)
# 2      PW32  POINT (-97.64161 30.37146)
# 3      PW31  POINT (-97.68382 30.38422)
# 4      PW30  POINT (-97.66285 30.37008)
# ..      ...                         ...
# 179   PAF50  POINT (-97.77022 30.29098)
# 180   PAF04  POINT (-97.77542 30.29641)
# 181   PAF03  POINT (-97.76675 30.33084)
# 182   PAF02  POINT (-97.76568 30.30814)
# 183   PAF01  POINT (-97.80762 30.34225)
#
# [184 rows x 2 columns]

# %%
route_coords.dtypes
# Out:
# Garb Rt       object
# geometry    geometry
# dtype: object

# %%
# This cycles through all of the route coords and prints the coords with the zip code. Next step, change the print to a return, and then apply it to a new zip column in the route_df. 
#DICT TO CONTAIN POINT AND ZIP
point_and_route = {"point":[], "zip":[]};
for j in route_coords['geometry']:
    idx = 0
    found = 0
    while (found == 0):
        if Point(j).within(zip_coords['geometry'][idx]) or Point(j).intersects(zip_coords['geometry'][idx]):
            point_and_route["point"].append(str(j))
            point_and_route["zip"].append(str(zip_coords['zipcode'][idx]))
            found = 1
        else:
            idx += 1

# %%
route_coords["POINT"] = point_and_route["point"]
# Out:
# /usr/local/lib/python3.7/dist-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
route_coords["ZIP"] = point_and_route["zip"]
# Out:
# /usr/local/lib/python3.7/dist-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
route_coords
# Out:
#     Garb Rt  ...    ZIP
# 0      PW41  ...  78754
# 1      PW40  ...  78753
# 2      PW32  ...  78754
# 3      PW31  ...  78753
# 4      PW30  ...  78754
# ..      ...  ...    ...
# 179   PAF50  ...  78703
# 180   PAF04  ...  78703
# 181   PAF03  ...  78731
# 182   PAF02  ...  78703
# 183   PAF01  ...  78746
#
# [184 rows x 4 columns]

# %%
# Import df_2017_routes (from waste_data_etl and on S3)
df_2017_routes = pd.read_csv("s3://finalprojectaustintrash/routes_2017_weight.csv")
df_2017_routes.head()
# Out:
#   route_number  load_weight                                           the_geom
# 0        PAF01     632960.0  MULTIPOLYGON (((-97.80021375787697 30.36733765...
# 1        PAF02     678100.0  MULTIPOLYGON (((-97.77221898831849 30.32271999...
# 2        PAF03     649520.0  MULTIPOLYGON (((-97.7601229300713 30.340361143...
# 3        PAF04     651640.0  MULTIPOLYGON (((-97.77662750513846 30.30588241...
# 4        PAF50     545080.0  MULTIPOLYGON (((-97.7724542400386 30.297463218...

# %%
 #Merge route_cords and df_2017_routes (from waste_data_etl and on S3) on Garb Rt AND route_number to have the weight added to the first or the zip to the second

# %%
# confirm there is only one zip code per route (there are multiple routes per zipcode)

# %%
# list the routes per zip i.e for zip 78754 routes are PW41,PW32 and PW30 AND sum the weight per zipcode like groupby.(ZIP).su

# %%
# Import full_zip_codes table
df_full_zip_codes = pd.read_csv("s3://finalprojectaustintrash/full_zip_codes.csv")
df_full_zip_codes.head()

# %%
# Add (merge or append?) the weight per zip code to the full_zip_codes table. AND the if possible add the list of routes per zipcode
df_zipcodes_housing_grb = 
df_zipcodes_housing_grb.head()

# %%
#Drop na
df_zipcodes_housing_grb = df_zipcodes_housing_grb.dropna()
df_zipcodes_housing_grb.head()

# %%
# Export final table the one to feed the model (full_zip_codes table PLUS weight and if possible routes)
# Can we export it directly to S3?
df_zipcodes_housing_grb.to_csv("Austin_zipcodes_housing_grb.csv")

# %%
# This cycles through all of the route coords and prints the coords with the zip code. Next step, change the print to a return, and then apply it to a new zip column in the route_df. 

for j in route_coords['geometry']:
  idx = 0 
  found = 0
  while (found == 0):
    
      if Point(j).within(zip_coords['geometry'][idx]) or Point(j).intersects(zip_coords['geometry'][idx]):
        print("Route coordinate " + str(j) + " is within " + str(zip_coords['zipcode'][idx]))
        found = 1
      else:
        idx += 1
# Out:
# Route coordinate POINT (-97.66989257 30.35876415) is within 78754
# Route coordinate POINT (-97.67499719 30.36325543) is within 78753
# Route coordinate POINT (-97.64161360999999 30.37145619) is within 78754
# Route coordinate POINT (-97.68381677000001 30.38422137) is within 78753
# Route coordinate POINT (-97.66284967999999 30.37007561) is within 78754
# Route coordinate POINT (-97.73279568 30.20325809) is within 78744
# Route coordinate POINT (-97.69497543 30.39644282) is within 78758
# Route coordinate POINT (-97.69955125 30.39597405) is within 78758
# Route coordinate POINT (-97.66796929 30.39818178) is within 78753
# Route coordinate POINT (-97.66960129 30.38997468) is within 78753
# Route coordinate POINT (-97.6726405 30.43033551) is within 78728
# Route coordinate POINT (-97.73912405999999 30.19830731) is within 78744
# Route coordinate POINT (-97.7453337 30.19699304) is within 78744
# Route coordinate POINT (-97.75034690000001 30.19927324) is within 78744
# Route coordinate POINT (-97.71946995 30.23651855) is within 78741
# Route coordinate POINT (-97.74376631 30.22501638) is within 78741
# Route coordinate POINT (-97.74573616000001 30.23827842) is within 78704
# Route coordinate POINT (-97.74469434 30.24757604) is within 78704
# Route coordinate POINT (-97.75515987999999 30.2000353) is within 78744
# Route coordinate POINT (-97.76612667000001 30.20840788) is within 78745
# Route coordinate POINT (-97.74523959999999 30.15929573) is within 78747
# Route coordinate POINT (-97.75678449999999 30.17140911) is within 78744
# Route coordinate POINT (-97.76511696999999 30.17693276) is within 78744
# Route coordinate POINT (-97.78495929 30.18971342) is within 78745
# Route coordinate POINT (-97.79142121 30.17656273) is within 78748
# Route coordinate POINT (-97.76905806000001 30.18135791) is within 78744
# Route coordinate POINT (-97.79771862 30.19407128) is within 78745
# Route coordinate POINT (-97.80097402 30.17973622) is within 78748
# Route coordinate POINT (-97.81721603 30.16583273) is within 78748
# Route coordinate POINT (-97.80489725 30.18469376) is within 78748
# Route coordinate POINT (-97.8281791 30.16172781) is within 78748
# Route coordinate POINT (-97.82671039 30.1801728) is within 78748
# Route coordinate POINT (-97.64917317 30.2168308) is within 78725
# Route coordinate POINT (-97.69569684 30.23372156) is within 78741
# Route coordinate POINT (-97.69903293 30.23089232) is within 78741
# Route coordinate POINT (-97.70025266 30.3532138) is within 78753
# Route coordinate POINT (-97.68880114 30.36650486) is within 78753
# Route coordinate POINT (-97.67541549000001 30.33648218) is within 78754
# Route coordinate POINT (-97.61786834999999 30.30017843) is within 78724
# Route coordinate POINT (-97.64383011 30.3181349) is within 78724
# Route coordinate POINT (-97.68963152000001 30.37916313) is within 78758
# Route coordinate POINT (-97.70096821999999 30.37363095) is within 78758
# Route coordinate POINT (-97.70231424000001 30.38486659) is within 78758
# Route coordinate POINT (-97.74318528000001 30.30411963) is within 78705
# Route coordinate POINT (-97.69794778000001 30.27163951) is within 78702
# Route coordinate POINT (-97.75875477 30.27779443) is within 78703
# Route coordinate POINT (-97.7419625 30.27318917) is within 78701
# Route coordinate POINT (-97.71875287 30.30947366) is within 78751
# Route coordinate POINT (-97.7165747 30.26711849) is within 78702
# Route coordinate POINT (-97.71817427000001 30.29100564) is within 78722
# Route coordinate POINT (-97.70450173 30.29836047) is within 78723
# Route coordinate POINT (-97.74626734 30.29047854) is within 78705
# Route coordinate POINT (-97.73190873999999 30.29309202) is within 78705
# Route coordinate POINT (-97.72857752 30.3061255) is within 78751
# Route coordinate POINT (-97.78447864 30.42806171) is within 78750
# Route coordinate POINT (-97.80819617 30.44263863) is within 78750
# Route coordinate POINT (-97.80304759999999 30.4237094) is within 78750
# Route coordinate POINT (-97.83950513000001 30.41483996) is within 78726
# Route coordinate POINT (-97.79959168000001 30.43355648) is within 78750
# Route coordinate POINT (-97.82297964999999 30.44804995) is within 78726
# Route coordinate POINT (-97.59998154 30.35105069) is within 78653
# Route coordinate POINT (-97.66746194 30.18706204) is within 78719
# Route coordinate POINT (-97.61640475999999 30.1711068) is within 78617
# Route coordinate POINT (-97.65031714 30.40615276) is within 78753
# Route coordinate POINT (-97.6171887 30.35554618) is within 78754
# Route coordinate POINT (-97.75198274 30.44352137) is within 78729
# Route coordinate POINT (-97.7723293 30.42696644) is within 78759
# Route coordinate POINT (-97.77473104000001 30.4188949) is within 78759
# Route coordinate POINT (-97.77136794 30.39555977) is within 78759
# Route coordinate POINT (-97.76057108000001 30.40912919) is within 78759
# Route coordinate POINT (-97.75813539000001 30.41910969) is within 78759
# Route coordinate POINT (-97.7137017 30.40751645) is within 78758
# Route coordinate POINT (-97.71183151 30.41931046) is within 78759
# Route coordinate POINT (-97.70288814 30.43874905) is within 78727
# Route coordinate POINT (-97.73786014 30.40440069) is within 78759
# Route coordinate POINT (-97.73320751999999 30.42658368) is within 78727
# Route coordinate POINT (-97.68929678000001 30.42920044) is within 78727
# Route coordinate POINT (-97.77144108 30.45133449) is within 78729
# Route coordinate POINT (-97.7718328 30.50271848) is within 78717
# Route coordinate POINT (-97.76472287 30.49571302) is within 78717
# Route coordinate POINT (-97.75224348 30.5051126) is within 78717
# Route coordinate POINT (-97.79763810999999 30.49267722) is within 78717
# Route coordinate POINT (-97.78686508 30.46362426) is within 78729
# Route coordinate POINT (-97.80882919 30.23077475) is within 78745
# Route coordinate POINT (-97.78292789 30.24821522) is within 78704
# Route coordinate POINT (-97.83667462 30.25383273) is within 78735
# Route coordinate POINT (-97.81606687999999 30.27374759) is within 78746
# Route coordinate POINT (-97.79613227999999 30.27066998) is within 78746
# Route coordinate POINT (-97.78672014 30.21077517) is within 78745
# Route coordinate POINT (-97.778586 30.20675839) is within 78745
# Route coordinate POINT (-97.78538485 30.20184734) is within 78745
# Route coordinate POINT (-97.8004323 30.20666075) is within 78745
# Route coordinate POINT (-97.81675859999999 30.21499462) is within 78745
# Route coordinate POINT (-97.77619518 30.25458699) is within 78704
# Route coordinate POINT (-97.76758447 30.26075019) is within 78704
# Route coordinate POINT (-97.75902837 30.24434593) is within 78704
# Route coordinate POINT (-97.759564 30.25332679) is within 78704
# Route coordinate POINT (-97.80402951000001 30.2186777) is within 78745
# Route coordinate POINT (-97.78778407999999 30.22787445) is within 78745
# Route coordinate POINT (-97.77911906999999 30.22102123) is within 78745
# Route coordinate POINT (-97.76606377 30.23354011) is within 78704
# Route coordinate POINT (-97.77598557 30.2388032) is within 78704
# Route coordinate POINT (-97.85183324 30.24555427) is within 78735
# Route coordinate POINT (-97.84844131 30.23028355) is within 78749
# Route coordinate POINT (-97.89586515000001 30.25300656) is within 78735
# Route coordinate POINT (-97.89292924999999 30.23826459) is within 78736
# Route coordinate POINT (-97.81957826999999 30.20023071) is within 78745
# Route coordinate POINT (-97.84250948 30.18956227) is within 78748
# Route coordinate POINT (-97.82539369 30.19158215) is within 78745
# Route coordinate POINT (-97.81726644 30.19384437) is within 78745
# Route coordinate POINT (-97.83321089 30.20583871) is within 78745
# Route coordinate POINT (-97.84278345 30.20559723) is within 78749
# Route coordinate POINT (-97.8035931 30.14170739) is within 78652
# Route coordinate POINT (-97.74331017 30.15237199) is within 78747
# Route coordinate POINT (-97.78215054 30.1404979) is within 78747
# Route coordinate POINT (-97.77711838 30.14676325) is within 78747
# Route coordinate POINT (-97.72430554 30.16333659) is within 78744
# Route coordinate POINT (-97.75956711000001 30.19204945) is within 78744
# Route coordinate POINT (-97.86581992000001 30.22142015) is within 78749
# Route coordinate POINT (-97.87669303 30.21524872) is within 78749
# Route coordinate POINT (-97.87543076 30.22726818) is within 78749
# Route coordinate POINT (-97.84809310999999 30.20968466) is within 78749
# Route coordinate POINT (-97.85528228 30.19935845) is within 78749
# Route coordinate POINT (-97.85100554 30.21752904) is within 78749
# Route coordinate POINT (-97.83827474 30.16423859) is within 78748
# Route coordinate POINT (-97.83846240000001 30.17505459) is within 78748
# Route coordinate POINT (-97.8333554 30.18407939) is within 78748
# Route coordinate POINT (-97.83849915 30.15132371) is within 78748
# Route coordinate POINT (-97.85634695 30.14834064) is within 78739
# Route coordinate POINT (-97.90996507 30.17641761) is within 78739
# Route coordinate POINT (-97.88555881000001 30.21160525) is within 78749
# Route coordinate POINT (-97.87355782 30.19606697) is within 78739
# Route coordinate POINT (-97.88840938 30.1796546) is within 78739
# Route coordinate POINT (-97.88888296 30.19741055) is within 78739
# Route coordinate POINT (-97.92387825 30.18106669) is within 78739
# Route coordinate POINT (-97.71322032 30.36727167) is within 78758
# Route coordinate POINT (-97.71415011000001 30.37932368) is within 78758
# Route coordinate POINT (-97.72963177 30.36503493) is within 78757
# Route coordinate POINT (-97.74753327000001 30.37262491) is within 78759
# Route coordinate POINT (-97.75629524999999 30.3812887) is within 78759
# Route coordinate POINT (-97.7185535 30.33051573) is within 78752
# Route coordinate POINT (-97.6895774 30.31632456) is within 78723
# Route coordinate POINT (-97.69703371 30.32942332) is within 78752
# Route coordinate POINT (-97.70055656 30.31219648) is within 78723
# Route coordinate POINT (-97.7088332 30.33990245) is within 78752
# Route coordinate POINT (-97.69452879000001 30.30697014) is within 78723
# Route coordinate POINT (-97.72357724 30.35428201) is within 78757
# Route coordinate POINT (-97.72677686999999 30.3445778) is within 78757
# Route coordinate POINT (-97.73205843 30.33801574) is within 78757
# Route coordinate POINT (-97.7445522 30.34287175) is within 78757
# Route coordinate POINT (-97.74083846000001 30.35109427) is within 78757
# Route coordinate POINT (-97.71282512000001 30.35773952) is within 78758
# Route coordinate POINT (-97.64182285 30.27392508) is within 78725
# Route coordinate POINT (-97.66887183999999 30.26012814) is within 78725
# Route coordinate POINT (-97.67359851000001 30.30164251) is within 78723
# Route coordinate POINT (-97.67824338 30.30957508) is within 78723
# Route coordinate POINT (-97.67369633 30.31645829) is within 78723
# Route coordinate POINT (-97.75246357 30.36630507) is within 78731
# Route coordinate POINT (-97.76344852 30.36825553) is within 78731
# Route coordinate POINT (-97.76365289 30.3513775) is within 78731
# Route coordinate POINT (-97.7685053 30.34706529) is within 78731
# Route coordinate POINT (-97.77812485 30.37234484) is within 78731
# Route coordinate POINT (-97.82545129 30.38722749) is within 78730
# Route coordinate POINT (-97.72086509 30.25293531) is within 78702
# Route coordinate POINT (-97.70758019 30.26317795) is within 78702
# Route coordinate POINT (-97.70092513 30.25437068) is within 78702
# Route coordinate POINT (-97.72500731 30.2583562) is within 78702
# Route coordinate POINT (-97.68709478 30.2732848) is within 78721
# Route coordinate POINT (-97.67436642 30.28805316) is within 78723
# Route coordinate POINT (-97.6807733 30.26941898) is within 78721
# Route coordinate POINT (-97.69319777 30.28824637) is within 78723
# Route coordinate POINT (-97.72476028 30.31834639) is within 78751
# Route coordinate POINT (-97.74855089 30.31808151) is within 78756
# Route coordinate POINT (-97.74659914999999 30.32776786) is within 78756
# Route coordinate POINT (-97.75120758 30.30201345) is within 78703
# Route coordinate POINT (-97.7280717 30.26273893) is within 78702
# Route coordinate POINT (-97.72189947 30.28002117) is within 78722
# Route coordinate POINT (-97.71311287 30.28376277) is within 78722
# Route coordinate POINT (-97.75990965 30.28896278) is within 78703
# Route coordinate POINT (-97.77021897 30.29097973) is within 78703
# Route coordinate POINT (-97.77542129 30.29641263) is within 78703
# Route coordinate POINT (-97.76674749999999 30.33084492) is within 78731
# Route coordinate POINT (-97.76567716 30.30814288) is within 78703
# Route coordinate POINT (-97.80762299 30.34225055) is within 78746

# %%
# We need this part because it needs to go through each polygon to check the route points
#def find_within_zipcode(coord):
  # for each row in zip_coords, is coord in that row's polygon?
  #return current_row["zipcode"]

def find_zipcode(row): 
    try:
      coord = route_coord["geometry"]
      # if find_within_zipcode returns something, return that value from this function
      # else, return null value
      if coord.within(zip_coords['geometry'][row.index]) or coord.intersects(zip_coords['geometry'][row.index]):
        return zip_coords["zipcode"][row.index]
    except:
      return "00000"

# %%
# This is to tinker with to see if we can get it to work.
# idx = 0
# for j in route_coords["geometry"].values:
#     try:
#       if Point(j).within(zip_coords['geometry'][idx]) or Point(j).intersects(zip_coords['geometry'][idx]):
#         routes_coords.append(j, zip_coords['zipcode'][idx])
#     except:
#       pass
#     idx+=1

# %%
route_coords["zip"] = route_coords.apply(
    lambda row: find_zipcode(row), axis=1)
print(route_coords)

# %%
set(route_coords["zip"].values)
